# %%
import pandas as pd
import numpy as np

# %%
player_df = pd.read_csv('player_data.csv')
player_df.head()
# Out:
#    ID  points  possessions  team_pace  Unnamed: 4  Unnamed: 5    GP   MPG  \
# 0   1  1893.0       1251.8       97.8         NaN         NaN  63.0  33.9
# 1   2  1386.0       1282.5      110.5         NaN         NaN  58.0  32.5
# 2   3  1405.0       1252.3      105.8         NaN         NaN  55.0  36.3
# 3   4  1282.0       1235.9      100.7         NaN         NaN  54.0  37.6
# 4   5  1721.0       1254.0      105.7         NaN         NaN  59.0  30.5
#
#      TS%   AST    TO   USG  ORR   DRR  REBR    PER
# 0  0.569  17.2  11.5  26.1  4.7  23.3   7.8  10.90
# 1  0.511  24.8   9.7  26.9  6.1   0.9  10.7  27.30
# 2  0.605  25.7  13.9  28.1  4.5   4.9   1.8    NaN
# 3  0.636  29.5  11.0  22.3  4.8   4.6   5.6  22.35
# 4  0.589  22.8   9.9  24.6  1.2   8.4  12.1  28.38

# %%
player_df.isna().sum(axis=0)
# Out:
# ID              0
# points          3
# possessions     3
# team_pace       3
# Unnamed: 4     46
# Unnamed: 5     46
# GP              7
# MPG             6
# TS%             1
# AST             1
# TO              1
# USG             1
# ORR             1
# DRR             1
# REBR            1
# PER            10
# dtype: int64

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           46 non-null     int64
#  1   points       43 non-null     float64
#  2   possessions  43 non-null     float64
#  3   team_pace    43 non-null     float64
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   0 non-null      float64
#  6   GP           39 non-null     float64
#  7   MPG          40 non-null     float64
#  8   TS%          45 non-null     float64
#  9   AST          45 non-null     float64
#  10  TO           45 non-null     float64
#  11  USG          45 non-null     float64
#  12  ORR          45 non-null     float64
#  13  DRR          45 non-null     float64
#  14  REBR         45 non-null     float64
#  15  PER          36 non-null     float64
# dtypes: float64(15), int64(1)
# memory usage: 5.9 KB

# %%
player_df.dropna(how='all', axis=1, inplace=True)
player_df.isna().sum()
# Out:
# ID              0
# points          3
# possessions     3
# team_pace       3
# GP              7
# MPG             6
# TS%             1
# AST             1
# TO              1
# USG             1
# ORR             1
# DRR             1
# REBR            1
# PER            10
# dtype: int64

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           46 non-null     int64
#  1   points       43 non-null     float64
#  2   possessions  43 non-null     float64
#  3   team_pace    43 non-null     float64
#  4   GP           39 non-null     float64
#  5   MPG          40 non-null     float64
#  6   TS%          45 non-null     float64
#  7   AST          45 non-null     float64
#  8   TO           45 non-null     float64
#  9   USG          45 non-null     float64
#  10  ORR          45 non-null     float64
#  11  DRR          45 non-null     float64
#  12  REBR         45 non-null     float64
#  13  PER          36 non-null     float64
# dtypes: float64(13), int64(1)
# memory usage: 5.2 KB

# %%
ind = player_df.dropna(how='all').isna().sum(axis=1).argmax()
player_df.iloc[ind]
# Out:
# ID               30.0
# points         1645.0
# possessions    1415.7
# team_pace       109.8
# GP                NaN
# MPG               NaN
# TS%               NaN
# AST               NaN
# TO                NaN
# USG               NaN
# ORR               NaN
# DRR               NaN
# REBR              NaN
# PER               NaN
# Name: 29, dtype: float64

# %%
player_df
# Out:
#     ID  points  possessions  team_pace    GP   MPG    TS%   AST    TO   USG  \
# 0    1  1893.0       1251.8       97.8  63.0  33.9  0.569  17.2  11.5  26.1
# 1    2  1386.0       1282.5      110.5  58.0  32.5  0.511  24.8   9.7  26.9
# 2    3  1405.0       1252.3      105.8  55.0  36.3  0.605  25.7  13.9  28.1
# 3    4  1282.0       1235.9      100.7  54.0  37.6  0.636  29.5  11.0  22.3
# 4    5  1721.0       1254.0      105.7  59.0  30.5  0.589  22.8   9.9  24.6
# 5    6  1004.0       1322.4      102.1  57.0  36.3  0.574  20.3  13.5  31.0
# 6    7  1920.0       1207.6      109.8  55.0  37.0  0.573  26.0  13.1  30.7
# 7    8  1353.0       1348.1      112.2  57.0   NaN  0.574  24.4  11.3  26.3
# 8    9     NaN          NaN        NaN  54.0  31.7  0.577  24.6  14.4  35.7
# 9   10  1468.0       1400.9       93.7  61.0  35.6  0.547  22.9  12.2  22.7
# 10  11  1856.0       1303.8       93.4  55.0  33.6  0.563  28.9  14.7  26.7
# ...

# %%
player_df.dropna(thresh=12, inplace=True)
player_df
# Out:
#     ID  points  possessions  team_pace    GP   MPG    TS%   AST    TO   USG  \
# 0    1  1893.0       1251.8       97.8  63.0  33.9  0.569  17.2  11.5  26.1
# 1    2  1386.0       1282.5      110.5  58.0  32.5  0.511  24.8   9.7  26.9
# 2    3  1405.0       1252.3      105.8  55.0  36.3  0.605  25.7  13.9  28.1
# 3    4  1282.0       1235.9      100.7  54.0  37.6  0.636  29.5  11.0  22.3
# 4    5  1721.0       1254.0      105.7  59.0  30.5  0.589  22.8   9.9  24.6
# 5    6  1004.0       1322.4      102.1  57.0  36.3  0.574  20.3  13.5  31.0
# 6    7  1920.0       1207.6      109.8  55.0  37.0  0.573  26.0  13.1  30.7
# 7    8  1353.0       1348.1      112.2  57.0   NaN  0.574  24.4  11.3  26.3
# 9   10  1468.0       1400.9       93.7  61.0  35.6  0.547  22.9  12.2  22.7
# 10  11  1856.0       1303.8       93.4  55.0  33.6  0.563  28.9  14.7  26.7
# 11  12  1058.0       1231.5       99.4  63.0  32.8  0.550  25.1  12.9  27.2
# ...

# %%
player_df.any()
# Out:
# ID             True
# points         True
# possessions    True
# team_pace      True
# GP             True
# MPG            True
# TS%            True
# AST            True
# TO             True
# USG            True
# ORR            True
# DRR            True
# REBR           True
# PER            True
# dtype: bool

# %%
player_df.reset_index(drop=True,inplace=True)
player_df
# Out:
#     ID  points  possessions  team_pace    GP   MPG    TS%   AST    TO   USG  \
# 0    1  1893.0       1251.8       97.8  63.0  33.9  0.569  17.2  11.5  26.1
# 1    2  1386.0       1282.5      110.5  58.0  32.5  0.511  24.8   9.7  26.9
# 2    3  1405.0       1252.3      105.8  55.0  36.3  0.605  25.7  13.9  28.1
# 3    4  1282.0       1235.9      100.7  54.0  37.6  0.636  29.5  11.0  22.3
# 4    5  1721.0       1254.0      105.7  59.0  30.5  0.589  22.8   9.9  24.6
# 5    6  1004.0       1322.4      102.1  57.0  36.3  0.574  20.3  13.5  31.0
# 6    7  1920.0       1207.6      109.8  55.0  37.0  0.573  26.0  13.1  30.7
# 7    8  1353.0       1348.1      112.2  57.0   NaN  0.574  24.4  11.3  26.3
# 8   10  1468.0       1400.9       93.7  61.0  35.6  0.547  22.9  12.2  22.7
# 9   11  1856.0       1303.8       93.4  55.0  33.6  0.563  28.9  14.7  26.7
# 10  12  1058.0       1231.5       99.4  63.0  32.8  0.550  25.1  12.9  27.2
# ...

# %%
player_df.drop(columns=['ID']).describe()
# Out:
#             points  possessions   team_pace         GP       MPG        TS%  \
# count    42.000000    42.000000   42.000000  36.000000  37.00000  42.000000
# mean   1592.380952  1346.323810  106.526190  59.861111  35.27027   0.596357
# std     351.876707   214.503887    6.676791   5.576239   1.91135   0.029284
# min     183.000000   147.300000   89.700000  48.000000  30.50000   0.511000
# 25%    1390.750000  1283.650000  102.400000  55.750000  34.10000   0.572250
# 50%    1680.000000  1369.800000  106.800000  60.500000  35.40000   0.604000
# 75%    1826.250000  1444.050000  111.950000  64.000000  36.90000   0.618750
# max    2062.000000  1542.000000  118.800000  69.000000  38.80000   0.645000
#
#              AST         TO        USG        ORR        DRR       REBR  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean   26.221429  13.083333  30.478571   4.280952  14.850000   8.497619
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = list(player_df)[1:]
cols
# Out:
# ['points',
#  'possessions',
#  'team_pace',
#  'GP',
#  'MPG',
#  'TS%',
#  'AST',
#  'TO',
#  'USG',
#  'ORR',
#  'DRR',
#  'REBR',
#  'PER']

# %%
cols = list(player_df.iloc[:,1:])
cols
# Out:
# ['points',
#  'possessions',
#  'team_pace',
#  'GP',
#  'MPG',
#  'TS%',
#  'AST',
#  'TO',
#  'USG',
#  'ORR',
#  'DRR',
#  'REBR',
#  'PER']

# %%
fig, axes = plt.subplots(3,5, figsize=(18,11))
fig.tight_layout( pad=3.0)

for i in range(len(cols)):
    sns.boxplot(ax=axes[i//5,i%5], y=player_df[cols[i]])

# %%
fig = plt.figure(figsize=(18,11))
fig.tight_layout(pad=3.0)

for i in range(len(cols)):
    plt.subplot(3,5,i+1)
    data = player_df[cols[i]]
    plt.boxplot(x=data[~data.isna()])
    plt.title(cols[i])

# %%
points_outlier = player_df['points'].idxmin()
player_df.iloc[points_outlier]
#points_outlier
# Out:
# ID              40.000
# points         183.000
# possessions    147.300
# team_pace      118.100
# GP              63.000
# MPG             37.500
# TS%              0.623
# AST             31.200
# TO              13.500
# USG             34.700
# ORR              6.300
# DRR             18.700
# REBR            13.600
# PER             29.810
# Name: 35, dtype: float64

# %%
possession_outlier = player_df['possessions'].idxmin()
player_df.index[possession_outlier]

player_df.drop(possession_outlier,inplace=True)
player_df.tail(10)
# Out:
#     ID  points  possessions  team_pace    GP   MPG    TS%   AST    TO   USG  \
# 31  36  2062.0       1505.7      111.5   NaN  37.0  0.620  29.8  15.6  36.2
# 32  37  1845.0       1435.7      113.1  69.0  36.9  0.634  33.2  14.0  36.5
# 33  38  1778.0       1526.4      109.3  66.0  34.9  0.612  30.6  15.9  35.9
# 34  39  1901.0       1444.1      109.7  67.0  36.5  0.609  27.2  14.8  35.5
# 36  41  2030.0       1431.0      112.3  68.0  37.0  0.618  32.5  15.3  34.5
# 37  42  1631.0       1465.7      110.1  66.0  37.5  0.613  28.4  14.4  35.7
# 38  43  1828.0       1507.2      112.7  64.0  36.5  0.618  31.3  14.0  34.9
# 39  44  1821.0       1443.7      118.8  66.0  36.6  0.609  27.3  13.5  35.8
# 40  45  1740.0       1443.9      114.1  68.0  37.1  0.611  26.6  15.2  29.3
# 41  46  1993.0       1459.0      112.5   NaN  36.9  0.627  30.4  15.0  33.7
#
#     ORR   DRR  REBR    PER
# 31  4.9  23.9  14.7  27.86
# 32  4.1  21.5  16.4  34.26
# 33  5.5  18.8  13.7  28.65
# ...

# %%
player_df.reset_index(drop=True,inplace=True)
player_df.tail(10)
# Out:
#     ID  points  possessions  team_pace    GP   MPG    TS%   AST    TO   USG  \
# 31  36  2062.0       1505.7      111.5   NaN  37.0  0.620  29.8  15.6  36.2
# 32  37  1845.0       1435.7      113.1  69.0  36.9  0.634  33.2  14.0  36.5
# 33  38  1778.0       1526.4      109.3  66.0  34.9  0.612  30.6  15.9  35.9
# 34  39  1901.0       1444.1      109.7  67.0  36.5  0.609  27.2  14.8  35.5
# 35  41  2030.0       1431.0      112.3  68.0  37.0  0.618  32.5  15.3  34.5
# 36  42  1631.0       1465.7      110.1  66.0  37.5  0.613  28.4  14.4  35.7
# 37  43  1828.0       1507.2      112.7  64.0  36.5  0.618  31.3  14.0  34.9
# 38  44  1821.0       1443.7      118.8  66.0  36.6  0.609  27.3  13.5  35.8
# 39  45  1740.0       1443.9      114.1  68.0  37.1  0.611  26.6  15.2  29.3
# 40  46  1993.0       1459.0      112.5   NaN  36.9  0.627  30.4  15.0  33.7
#
#     ORR   DRR  REBR    PER
# 31  4.9  23.9  14.7  27.86
# 32  4.1  21.5  16.4  34.26
# 33  5.5  18.8  13.7  28.65
# ...

# %%
player_df.isna().sum()
# Out:
# ID             0
# points         0
# possessions    0
# team_pace      0
# GP             6
# MPG            5
# TS%            0
# AST            0
# TO             0
# USG            0
# ORR            0
# DRR            0
# REBR           0
# PER            9
# dtype: int64

# %%
fig = plt.figure(figsize=(18,11))
fig.tight_layout(pad=5.0)

for i in range(len(cols)):
    plt.subplot(3,5,i+1)
    data = player_df[cols[i]]
    plt.hist(data[~data.isna()],bins=30)
    plt.title(cols[i])

# %%
cols
# Out:
# ['points',
#  'possessions',
#  'team_pace',
#  'GP',
#  'MPG',
#  'TS%',
#  'AST',
#  'TO',
#  'USG',
#  'ORR',
#  'DRR',
#  'REBR',
#  'PER']

# %%
cols = list(player_df.iloc[:, 1:])

fig, axes = plt.subplots(3,5, figsize=(18,11))
#fig.tight_layout(pad=3.0)

for i in range(len(cols)):
    #sns.histplot(x=player_df[cols[i]], bins=30, ax=axes[i // 5, i % 5])
    sns.kdeplot(ax=axes[i//5, i%5], data=player_df[cols[i]]);
    pass
# Out:
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# ...

# %%
data = player_df['GP']
plt.hist(x=data[~data.isna()],bins=30, density=True)
sns.kdeplot(data[~data.isna()]);
# Out:
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
sns.histplot(data, bins=30,);

# %%
plt.hist(player_df['points'], bins=30,density=True)
plt.title('Points histogram')
sns.kdeplot(player_df['points'])
# Out:
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# c:\Users\karol\miniconda3\envs\myenv\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
player_df[player_df['points']>1600 ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 40
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           23 non-null     int64
#  1   points       23 non-null     float64
#  2   possessions  23 non-null     float64
#  3   team_pace    23 non-null     float64
#  4   GP           20 non-null     float64
#  5   MPG          20 non-null     float64
#  6   TS%          23 non-null     float64
#  7   AST          23 non-null     float64
#  8   TO           23 non-null     float64
#  9   USG          23 non-null     float64
#  10  ORR          23 non-null     float64
#  11  DRR          23 non-null     float64
#  12  REBR         23 non-null     float64
#  13  PER          20 non-null     float64
# dtypes: float64(13), int64(1)
# memory usage: 2.7 KB
